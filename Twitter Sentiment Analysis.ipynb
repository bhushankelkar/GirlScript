# %% [markdown]
# # Import the necessary libraries

# %%
import pandas as pd
import twint
import nest_asyncio
import re
import csv
import random
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import string
import nltk
import warnings
import json
import pickle
warnings.filterwarnings("ignore",category=DeprecationWarning)
# %matplotlib inline

# %%
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import KFold, cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.model_selection import GridSearchCV
from sklearn.externals import joblib
from nltk.corpus import stopwords
from nltk.tokenize import TweetTokenizer
from nltk.stem.wordnet import WordNetLemmatizer
from collections import Counter
from string import punctuation
from wordcloud import WordCloud

# %% [markdown]
# # PART 1
# # Read the data set

# %%
data = pd.read_csv('Sentiment Analysis Dataset.csv',encoding='latin')
data
# Out:
#           ItemID  Sentiment                                      SentimentText
# 0              1          0                       is so sad for my APL frie...
# 1              2          0                     I missed the New Moon trail...
# 2              3          1                            omg its already 7:30 :O
# 3              4          0            .. Omgaga. Im sooo  im gunna CRy. I'...
# 4              5          0           i think mi bf is cheating on me!!!   ...
# ...          ...        ...                                                ...
# 1048570  1048584          0  Missing my fiancee sooo badly!!!  I love you b...
# 1048571  1048585          0                                 missing my friend
# 1048572  1048586          0  Missing my friend and my cousin. Two months pa...
# 1048573  1048587          0                               missing my friends!
# 1048574  1048588          0                              Missing my friends!!
#
# [1048575 rows x 3 columns]

# %%
data = data[['Sentiment','SentimentText']]
data
# Out:
#          Sentiment                                      SentimentText
# 0                0                       is so sad for my APL frie...
# 1                0                     I missed the New Moon trail...
# 2                1                            omg its already 7:30 :O
# 3                0            .. Omgaga. Im sooo  im gunna CRy. I'...
# 4                0           i think mi bf is cheating on me!!!   ...
# ...            ...                                                ...
# 1048570          0  Missing my fiancee sooo badly!!!  I love you b...
# 1048571          0                                 missing my friend
# 1048572          0  Missing my friend and my cousin. Two months pa...
# 1048573          0                               missing my friends!
# 1048574          0                              Missing my friends!!
#
# [1048575 rows x 2 columns]

# %% [markdown]
# # Check for the distribution of the tweets

# %%
# check the number of positive vs. negative tagged sentences
positives = data['Sentiment'][data.Sentiment == 1]
negatives = data['Sentiment'][data.Sentiment == 0]


print('number of positve tagged sentences is:  {}'.format(len(positives)))
print('number of negative tagged sentences is: {}'.format(len(negatives)))
print('total length of the data is:            {}'.format(data.shape[0]))
# Out:
# number of positve tagged sentences is:  554470
# number of negative tagged sentences is: 494105
# total length of the data is:            1048575

# %% [markdown]
# # Get a word count per sentence column

# %%
def word_count(sentence):
    return len(sentence.split())
    
data['word count'] = data['SentimentText'].apply(word_count)
data.head(3)
# Out:
#    Sentiment                                      SentimentText  word count
# 0          0                       is so sad for my APL frie...           7
# 1          0                     I missed the New Moon trail...           6
# 2          1                            omg its already 7:30 :O           5

# %% [markdown]
# # Plot word count distribution for both positive and negative sentiments

# %%
x = data['word count'][data.Sentiment == 1]
y = data['word count'][data.Sentiment == 0]
plt.figure(figsize=(12,6))
plt.xlim(0,45)
plt.xlabel('word count')
plt.ylabel('frequency')
g = plt.hist([x, y], color=['r','b'], alpha=0.5, label=['positive','negative'])
plt.legend(loc='upper right')

# %% [markdown]
# # Get most common words in training dataset

# %%
all_words = []
for line in list(data['SentimentText']):
    words = line.split()
    for word in words:
        all_words.append(word.lower())
    
    
Counter(all_words).most_common(10)
# Out:
# [('i', 527539),
#  ('to', 352326),
#  ('the', 328179),
#  ('a', 246768),
#  ('you', 191230),
#  ('and', 189369),
#  ('my', 180043),
#  ('is', 143242),
#  ('it', 136775),
#  ('for', 136587)]

# %% [markdown]
# # Plot word frequency distribution of first few words

# %%
plt.figure(figsize=(12,5))
plt.title('Top 25 most common words')
plt.xticks(fontsize=13, rotation=90)
fd = nltk.FreqDist(all_words)
fd.plot(25,cumulative=False)

# log-log plot
word_counts = sorted(Counter(all_words).values(), reverse=True)
plt.figure(figsize=(12,5))
plt.loglog(word_counts, linestyle='-', linewidth=1.5)
plt.ylabel("Freq")
plt.xlabel("Word Rank")
plt.title('log-log plot of words frequency')
# Out:
# Text(0.5, 1.0, 'log-log plot of words frequency')

# %% [markdown]
# # PART 2
# # Twitter Data for Lockdown 1.0
# Reading the Lockdown 1.0 tweets dataset (India). The tweets have been fetched by using Twint. Keywords like "Corona", "Lockdown", "Pandemic", "PPE", "Work from home" were used to filter the desired tweets.

# %%
tweet = pd.read_csv('Lockdown1.0.csv')

# %%
tweet.head()
# Out:
#    Unnamed: 0                   id      conversation_id     created_at  \
# 0           0  1242879759601799168  1242745110661435393  1585160600000
# 1           1  1242879607176478720  1242879607176478720  1585160564000
# 2           2  1242879202866515969  1242450477779800065  1585160468000
# 3           3  1242878275585802240  1242873807137726464  1585160247000
# 4           4  1242876746459803658  1242717249590321157  1585159882000
#
#                   date  timezone place  \
# 0  2020-03-25 23:53:20       530   NaN
# 1  2020-03-25 23:52:44       530   NaN
# 2  2020-03-25 23:51:08       530   NaN
# 3  2020-03-25 23:47:27       530   NaN
# 4  2020-03-25 23:41:22       530   NaN
#
#                                                tweet hashtags cashtags  ...  \
# 0  The jio company launched their new plans calle...       []       []  ...
# 1  Reliance Jio offers free internet; Airtel, Vod...       []       []  ...
# 2  Yes home only... you can work from home!!!! Yo...       []       []  ...
# 3  Apart from the jokes, you may dm me if you nee...       []       []  ...
# 4                                  Work from home :P       []       []  ...
#
#                       geo  source user_rt_id user_rt  retweet_id  \
# 0  28.5934,77.2223,2000km     NaN        NaN     NaN         NaN
# 1  28.5934,77.2223,2000km     NaN        NaN     NaN         NaN
# 2  28.5934,77.2223,2000km     NaN        NaN     NaN         NaN
# 3  28.5934,77.2223,2000km     NaN        NaN     NaN         NaN
# 4  28.5934,77.2223,2000km     NaN        NaN     NaN         NaN
#
#                                             reply_to retweet_date  translate  \
# 0  [{'user_id': '853512722113323008', 'username':...          NaN        NaN
# 1  [{'user_id': '869018357432950785', 'username':...          NaN        NaN
# 2  [{'user_id': '804045415322554368', 'username':...          NaN        NaN
# 3  [{'user_id': '714465124782768128', 'username':...          NaN        NaN
# 4  [{'user_id': '276394575', 'username': 'hiren_r...          NaN        NaN
#
#    trans_src  trans_dest
# 0        NaN         NaN
# 1        NaN         NaN
# 2        NaN         NaN
# 3        NaN         NaN
# 4        NaN         NaN
#
# [5 rows x 34 columns]

# %%
tweet.to_pickle('df_lockdown.p')

# %%
df_lockdown = pd.read_pickle('df_lockdown.p')

# %% [markdown]
# # Word stemmer class

# %%
from nltk.stem import WordNetLemmatizer 
lemma = WordNetLemmatizer()
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Bhushan\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %% [markdown]
# # Text processing

# %%
def processTweet(tweet):
    # Remove HTML special entities (e.g. &amp;)
    tweet = re.sub(r'\&\w*;', '', tweet)
    #Convert @username to AT_USER
    tweet = re.sub('@[^\s]+','',tweet)
    # Remove tickers
    tweet = re.sub(r'\$\w*', '', tweet)
    # To lowercase
    tweet = tweet.lower()
    # Remove hyperlinks
    tweet = re.sub(r'https?:\/\/.*\/\w*', '', tweet)
    # Remove hashtags
    tweet = re.sub(r'#\w*', '', tweet)
    # Remove Punctuation and split 's, 't, 've with a space for filter
    tweet = re.sub(r'[' + punctuation.replace('@', '') + ']+', ' ', tweet)
    # Remove words with 2 or fewer letters
    tweet = re.sub(r'\b\w{1,2}\b', '', tweet)
    # Remove whitespace (including new line characters)
    tweet = re.sub(r'\s\s+', ' ', tweet)
    # Remove single space remaining at the front of the tweet.
    tweet = tweet.lstrip(' ') 
    tweet = [lemma.lemmatize(word) for word in tweet]
    # Remove characters beyond Basic Multilingual Plane (BMP) of Unicode:
    tweet = ''.join(c for c in tweet if c <= '\uFFFF') 
    return tweet
# ______________________________________________________________

# clean dataframe's text column
df_lockdown['tweet'] = df_lockdown['tweet'].apply(processTweet)
# preview some cleaned tweets
df_lockdown['tweet'].head()
# Out:
# 0    the jio company launched their new plans calle...
# 1    reliance jio offers free internet airtel voda ...
# 2        yes home only you can work from home you are
# 3    apart from the jokes you may you need anyone t...
# 4                                      work from home
# Name: tweet, dtype: object

# %%
before = df_lockdown['tweet'][100]
after = processTweet(before)

before,'\n',after
# Out:
# ('let sonia gandhi rahul gandhi and robert vadra start distributing their accumulated wealth poor people charity begins from home why can start helping poor people one banglow occupied this family spared isolation ward for covid patients convey them …',
#  '\n',
#  'let sonia gandhi rahul gandhi and robert vadra start distributing their accumulated wealth poor people charity begins from home why can start helping poor people one banglow occupied this family spared isolation ward for covid patients convey them …')

# %% [markdown]
# # plot word frequency distribution of first few words
# #  and log-log of all words

# %%
all_words = []
for line in list(df_lockdown['tweet']):
    words = line.split()
    for word in words:
        all_words.append(word.lower())


plt.figure(figsize=(12,5))
plt.xticks(fontsize=13, rotation=90)
fd = nltk.FreqDist(all_words)
fd.plot(25,cumulative=False)

 
word_counts = sorted(Counter(all_words).values(), reverse=True)

plt.figure(figsize=(12,5))
plt.loglog(word_counts, linestyle='-', linewidth=1.5)
plt.ylabel("Freq")
plt.xlabel("Word Rank")
# Out:
# Text(0.5, 0, 'Word Rank')

# %%
df_lockdown = df_lockdown.drop_duplicates('tweet')
df_lockdown.shape
# Out:
# (4074, 34)

# %% [markdown]
# # Tokenize helper function

# %%
def text_process(raw_text):
    """
    Takes in a string of text, then performs the following:
    1. Remove all punctuation
    2. Remove all stopwords
    3. Returns a list of the cleaned text
    """
    # Check characters to see if they are in punctuation
    nopunc = [char for char in list(raw_text) if char not in string.punctuation]

    # Join the characters again to form the string.
    nopunc = ''.join(nopunc)
    
    # Now just remove any stopwords
    return [word for word in nopunc.lower().split() if word.lower() not in stopwords.words('english')]
df_lockdown = df_lockdown.copy()
df_lockdown['tokens'] = df_lockdown['tweet'].apply(text_process) # tokenize style 1

# %% [markdown]
# # Most common words in twitter dataset

# %%
all_words = []
for ls in df_lockdown['tweet']:
    words = [w for w in ls]
    for word in words:
        all_words.append(word.lower())
    
# plot word frequency distribution of first few words
plt.figure(figsize=(12,5))
plt.xticks(fontsize=13, rotation=90)
fd = nltk.FreqDist(all_words)
fd.plot(25,cumulative=False)

# log-log  of all words 
word_counts = sorted(Counter(all_words).values(), reverse=True)
plt.figure(figsize=(12,5))
plt.loglog(word_counts, linestyle='-', linewidth=1.5)
plt.ylabel("Freq")
plt.xlabel("Word Rank")
# Out:
# Text(0.5, 0, 'Word Rank')

# %% [markdown]
# # Split sentences to get individual words

# %%
all_words = []
for line in df_lockdown['tokens']: # try 'tokens'
    all_words.extend(line)
    
# create a word frequency dictionary
wordfreq = Counter(all_words)

# draw a Word Cloud with word frequencies
wordcloud = WordCloud(width=900,
                      height=500,
                      max_words=500,
                      max_font_size=100,
                      relative_scaling=0.5,
                      colormap='Blues',
                      normalize_plurals=True).generate_from_frequencies(wordfreq)

plt.figure(figsize=(17,14))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# # Vectorize

# %%
bow_transformer = CountVectorizer(analyzer=text_process).fit(df_lockdown['tweet'])
# print total number of vocab words
print(len(bow_transformer.vocabulary_))
# Out:
# 12304

# %%
bow_transformer.vocabulary_
# Out:
# {'jio': 5790,
#  'company': 2687,
#  'launched': 6290,
#  'new': 7413,
#  'plans': 8160,
#  'called': 2228,
#  'work': 11695,
#  'home': 5109,
#  'reliance': 8951,
#  'offers': 7631,
#  'free': 4454,
#  'internet': 5594,
#  'airtel': 1132,
#  'voda': 11393,
#  'idea': 5297,
#  'promise': 8479,
#  'normal': 7506,
#  'needs': 7368,
#  '…': 12233,
#  'yes': 11871,
#  'apart': 1313,
#  'jokes': 5826,
#  'may': 6830,
#  'need': 7363,
#  'anyone': 1304,
#  'talk': 10447,
#  'away': 1566,
#  'lockdown': 6472,
#  'know': 6119,
#  'feels': 4243,
#  'like': 6402,
#  'hell': 5019,
#  'comforting': 2654,
#  'way': 11521,
#  'helpful': 5024,
#  'glad❤️': 4681,
#  'time': 10711,
#  'protect': 8497,
#  'covid': 2937,
#  'stage': 10075,
#  'people': 8022,
#  'stay': 10119,
#  'best': 1844,
#  'cure': 3025,
#  'question': 8660,
#  'economy': 3762,
#  'staving': 10118,
#  'mine': 6980,
#  'putting': 8590,
#  'kapoor': 5925,
#  'kanika': 5916,
#  'rana': 8755,
#  'different': 3419,
#  'corners': 2886,
#  'gives': 4675,
#  'fragrant': 4449,
#  'calmness': 2235,
#  'cheezein': 2450,
#  'nahi': 7258,
#  'mil': 6956,
#  'rahi': 8706,
#  'wohiii': 11683,
#  'khatam': 6037,
#  'hai': 4887,
#  'gai': 4549,
#  'working': 11702,
#  'tough': 10796,
#  'prevent': 8394,
#  'coming': 2658,
#  'local': 6462,
#  'nagar': 7253,
#  'nigam': 7441,
#  'workers': 11699,
#  'distributed': 3525,
#  'essential': 3978,
#  'things': 10642,
#  'collect': 2629,
#  'money': 7091,
#  'door': 3611,
#  'daily': 3087,
#  'worker': 11697,
#  'get': 4627,
#  'income': 5410,
#  'quarantine': 8647,
#  'hope': 5147,
#  'see': 9556,
#  'suggestion': 10276,
#  'thanks': 10611,
#  '–': 12152,
#  'shivalik': 9718,
#  'haridwar': 4944,
#  'put': 8587,
#  'stamp': 10080,
#  'hands': 4914,
#  'take': 10439,
#  'aadhaar': 874,
#  'pan': 7871,
#  'bank': 1693,
#  'details': 3322,
#  'later': 6279,
#  'check': 2439,
#  'health': 4991,
#  'every': 4003,
#  'week': 11553,
#  'stop': 10157,
#  'spread': 10042,
#  'hyderabad': 5261,
#  'state': 10103,
#  '60000': 643,
#  'airtravellers': 1133,
#  'still': 10145,
#  'tested': 10579,
#  'escaped': 3970,
#  'proper': 8488,
#  'checks': 2445,
#  'want': 11480,
#  'ask': 1442,
#  'there’': 10628,
#  'corresponding': 2897,
#  'fine': 4296,
#  'companies': 2685,
#  'don’': 3607,
#  'comply': 2718,
#  'regulations': 8917,
#  'mohalla': 7072,
#  'clinic': 2576,
#  'doctor': 3573,
#  'mohanpuri': 7076,
#  'maujpur': 6825,
#  'area': 1379,
#  'gopal': 4726,
#  'jha': 5775,
#  'found': 4435,
#  'request': 9025,
#  'visited': 11368,
#  '12th': 110,
#  'march': 6757,
#  '18th': 186,
#  'follow': 4386,
#  'days': 3130,
#  'pic': 8108,
#  'twitter': 10950,
#  'com': 2644,
#  'xouum13ekv': 11815,
#  'revoke': 9133,
#  'article': 1415,
#  '370': 486,
#  'become': 1779,
#  'silent': 9797,
#  'shutdown': 9766,
#  'services': 9628,
#  'due': 3684,
#  'security': 9555,
#  'purposes': 8576,
#  'whole': 11610,
#  'world': 11718,
#  'global': 4685,
#  'emergency': 3840,
#  'everyone': 4006,
#  'restored': 9092,
#  'aspirants': 1450,
#  'suffering': 10269,
#  'bad': 1623,
#  'connection': 2773,
#  'service': 9627,
#  'please': 8182,
#  'make': 6668,
#  'worthy': 11737,
#  'trust': 10910,
#  'recharge': 8845,
#  'plan': 8153,
#  'cannot': 2255,
#  'use': 11147,
#  'network': 7406,
#  'good': 4719,
#  'first': 4310,
#  'leave': 6328,
#  'office': 7632,
#  'option': 7734,
#  'ourself': 7777,
#  'show': 9744,
#  'mental': 6895,
#  'toughness': 10798,
#  'pass': 7943,
#  'crucial': 2993,
#  'phase': 8080,
#  'bhi': 1880,
#  'vha': 11297,
#  'tweet': 10944,
#  'kero': 6003,
#  'open': 7704,
#  'nhi': 7435,
#  'skta': 9862,
#  'wow': 11741,
#  'video': 11310,
#  'suggest': 10273,
#  'corona': 2887,
#  'asked': 1443,
#  'permission': 8046,
#  'enter': 3923,
#  'india': 5430,
#  'info': 5479,
#  'export': 4100,
#  'stopped': 10158,
#  'jan': 5744,
#  'half': 4897,
#  'knowledge': 6121,
#  'dangerous': 3102,
#  'many': 6747,
#  'fed': 4233,
#  'day': 3127,
#  'feed': 4236,
#  'much': 7175,
#  'next': 7422,
#  '3wk': 514,
#  'strt': 10207,
#  'frm': 4479,
#  'jazz': 5765,
#  'legend': 6337,
#  'manu': 6741,
#  'dibango': 3399,
#  'died': 3410,
#  'paris': 7912,
#  'aged': 1077,
#  'catching': 2315,
#  'coronavirus': 2890,
#  'known': 6123,
#  '1972': 195,
#  'song': 9952,
#  'soul': 9969,
#  'makossa': 6673,
#  'often': 7645,
#  'fused': 4522,
#  'funk': 4518,
#  'music': 7210,
#  'traditional': 10827,
#  'sounds': 9972,
#  'country': 2918,
#  'igshid': 5321,
#  '1fusp1s3k3uz5': 245,
#  'ghordi': 4644,
#  'highly': 5056,
#  'populated': 8256,
#  'back': 1617,
#  'outside': 7792,
#  'humbly': 5232,
#  'jitender': 5797,
#  'singh': 9818,
#  'kindly': 6080,
#  'centre': 2346,
#  'depute': 3289,
#  'incharge': 5402,
#  'officers': 7635,
#  'along': 1191,
#  'consider': 2782,
#  'sir': 9828,
#  'wishav': 11654,
#  'dev': 3331,
#  'president': 8383,
#  'block': 1954,
#  'indoor': 5446,
#  'safe': 9329,
#  'spidey': 10018,
#  'environmental': 3937,
#  'challenges': 2390,
#  'lets': 6359,
#  'healthy': 4995,
#  'vanish': 11231,
#  'pandemic': 7877,
#  'disease': 3485,
#  'shot': 9736,
#  '1lejmlzf47rm4': 284,
#  'finally': 4289,
#  'carelessness': 2284,
#  'gone': 4716,
#  'wiseness': 11652,
#  'high': 5050,
#  'keep': 5986,
#  'loved': 6529,
#  'ones': 7687,
#  'situation': 9845,
#  'washing': 11505,
#  'least': 6327,
#  'metres': 6923,
#  'meet': 6874,
#  'sending': 9592,
#  'lhhudsvdqo': 6378,
#  'protective': 8501,
#  'virus': 11355,
#  'wash': 11503,
#  'hand': 4907,
#  'cover': 2931,
#  'mouth': 7136,
#  'nose': 7511,
#  'mask': 6798,
#  'golves': 4713,
#  'tb8edjz2hr': 10490,
#  'announced': 1274,
#  'paid': 7847,
#  'holidays': 5107,
#  'possible': 8276,
#  'employees': 3856,
#  'everytime': 4011,
#  'think': 10644,
#  'would': 11738,
#  'hathway': 4963,
#  'always': 1207,
#  'disappointed': 3457,
#  'everyday': 4005,
#  'disconnected': 3468,
#  'person': 8056,
#  'kind': 6077,
#  'broadband': 2107,
#  'skmbrah3pf': 9861,
#  'sector': 9549,
#  'noida': 7490,
#  'wonder': 11686,
#  'shutting': 9769,
#  'clearly': 2567,
#  'worst': 11733,
#  'ever': 4002,
#  'someone': 9941,
#  'type': 10957,
#  'speed': 10005,
#  'yrjg240z5g': 11906,
#  'call': 2227,
#  'dubai': 3681,
#  'private': 8422,
#  'must': 7218,
#  '997340': 829,
#  'via': 11300,
#  '5f26eqf4wr': 615,
#  'four': 4438,
#  'cases': 2304,
#  'bandipora': 1677,
#  'positive': 8270,
#  'save': 9454,
#  'lives': 6447,
#  'one': 7686,
#  'seem': 9562,
#  'find': 4293,
#  'balance': 1653,
#  'anand': 1245,
#  'vallabh': 11221,
#  'vidyanagar': 11316,
#  'awesome': 1568,
#  'welcoming': 11570,
#  '❤': 12292,
#  'post': 8277,
#  'gujarat': 4835,
#  'tour': 10799,
#  'nov': 7527,
#  'dec': 3157,
#  '2019': 367,
#  'suggesting': 10275,
#  'folks': 4385,
#  '5wdopr6y23': 641,
#  'range': 8762,
#  'options': 7736,
#  'choose': 2502,
#  'let': 6358,
#  'ensure': 3920,
#  'together': 10756,
#  '175': 170,
#  'far': 4185,
#  'labourer': 6216,
#  'antresh': 1294,
#  'village': 11331,
#  'delhi': 3230,
#  'walking': 11474,
#  'wages': 11455,
#  'food': 4393,
#  'public': 8543,
#  'transport': 10852,
#  'done': 3602,
#  'vulnerable': 11426,
#  'cfpgv5ueax': 2362,
#  'struggling': 10213,
#  'activities': 980,
#  'thoda': 10655,
#  'aap': 887,
#  'kuch': 6170,
#  'sucks': 10261,
#  '9xgbaif2bj': 856,
#  'understand': 11034,
#  'cause': 2320,
#  'right': 9161,
#  'using': 11156,
#  'able': 911,
#  'believe': 1816,
#  'provide': 8515,
#  'hey': 5042,
#  'card': 2274,
#  'coverage': 2932,
#  'available': 1539,
#  'reply': 9005,
#  'asap': 1431,
#  'wrost': 11763,
#  'basis': 1732,
#  'problem': 8432,
#  'pack': 7828,
#  'nikal': 7452,
#  'diya': 3553,
#  'dedo': 3181,
#  'jaye': 5763,
#  'scam': 9472,
#  'shame': 9666,
#  'avg': 1542,
#  'improve': 5384,
#  'port': 8261,
#  'old': 7668,
#  'number': 7560,
#  'uynngjspnm': 11183,
#  'easy': 3747,
#  'feel': 4239,
#  'distant': 3516,
#  'passing': 7948,
#  'lunch': 6562,
#  'coffee': 2615,
#  'lucky': 6552,
#  'benefit': 1832,
#  '5sdojf5oxa': 636,
#  'team': 10501,
#  'appreciate': 1347,
#  'tata': 10479,
#  'aig': 1109,
#  'support': 10325,
#  'gaurav': 4598,
#  'incident': 5403,
#  '20200323409': 369,
#  'given': 4673,
#  'prompt': 8484,
#  'followed': 4387,
#  'case': 2303,
#  'appreciated': 1348,
#  'expectation': 4067,
#  'reality': 8821,
#  'holiday': 5106,
#  'kis': 6087,
#  'sath': 9440,
#  'rha': 9142,
#  'aisa': 1134,
#  'auswiwauli': 1522,
#  'evening': 3998,
#  'dhananjay': 3362,
#  'chauhan': 2434,
#  'bihar': 1902,
#  'raising': 8724,
#  'issue': 5669,
#  'emi': 3841,
#  'loan': 6458,
#  'dhfl': 3379,
#  'difficult': 3422,
#  'give': 4670,
#  'months': 7103,
#  'government': 4742,
#  'finance': 4290,
#  'minister': 6994,
#  'wave': 11519,
#  'current': 3034,
#  'something': 9942,
#  'women': 11685,
#  'really': 8826,
#  'follows': 4390,
#  'schedule': 9487,
#  'morning': 7114,
#  'till': 10709,
#  'midnight': 6941,
#  'engaged': 3897,
#  'homely': 5114,
#  'task': 10472,
#  'happy': 4931,
#  'helping': 5025,
#  'today': 10751,
#  'cooking': 2864,
#  'dinner': 3440,
#  'wife': 11627,
#  'tjj84n7wa2ne': 10736,
#  'ordered': 7742,
#  'wifi': 11628,
#  'adapter': 991,
#  'useful': 11151,
#  'last': 6274,
#  'saturday': 9446,
#  'yet': 11874,
#  'delivered': 3239,
#  'reached': 8802,
#  'final': 4286,
#  'center': 2341,
#  'help': 5021,
#  'getting': 4629,
#  'early': 3730,
#  'point': 8222,
#  'basically': 1730,
#  'also': 1201,
#  'bcz': 1761,
#  'problematic': 8433,
#  'anyways': 1308,
#  'reported': 9008,
#  'doctors': 3574,
#  'viral': 11346,
#  'letters': 6362,
#  'nitish': 7470,
#  'kumar': 6177,
#  'nmch': 7478,
#  '36750': 485,
#  'never': 7411,
#  'felt': 4248,
#  'pls': 8191,
#  'district': 3531,
#  'hospital': 5159,
#  'dewas': 3351,
#  'sanitizer': 9411,
#  'kit': 6093,
#  'guide': 4828,
#  'staff': 10073,
#  'class': 2550,
#  'comes': 2651,
#  'hygine': 5266,
#  'nurses': 7566,
#  'safai': 9328,
#  'sindh': 9812,
#  'approved': 1358,
#  'purchase': 8568,
#  '290': 422,
#  'ventilators': 11279,
#  'million': 6970,
#  'items': 5679,
#  'ppe': 8306,
#  'portable': 8262,
#  'ray': 8788,
#  'machines': 6602,
#  '100': 43,
#  'rapid': 8769,
#  'antigen': 1292,
#  'test': 10578,
#  'used': 11149,
#  'china': 2482,
#  'deal': 3145,
#  'well': 11572,
#  'tmhskjso1k': 10744,
#  'nenaikkere': 7390,
#  'worries': 11725,
#  'solution': 9933,
#  'communication': 2677,
#  'unlimited': 11082,
#  'messaging': 6913,
#  'scheduling': 9488,
#  'chat': 2431,
#  'search': 9528,
#  'app': 1326,
#  'capabilities': 2260,
#  'jhbvn0kkf8': 5781,
#  'tips': 10724,
#  'elders': 3808,
#  'spending': 10009,
#  'lock': 6470,
#  'kinda': 6078,
#  'life': 6387,
#  'closed': 2583,
#  'room': 9231,
#  'years': 11865,
#  'maharashtra': 6636,
#  'govt': 4749,
#  'decided': 3165,
#  'vegetables': 11263,
#  'fruits': 4490,
#  'grocery': 4792,
#  'bakery': 1644,
#  'exempted': 4047,
#  'vendors': 11275,
#  'deliveries': 3241,
#  'taking': 10443,
#  'appropriate': 1355,
#  'care': 2277,
#  'police': 8227,
#  'facilitate': 4141,
#  'movment': 7145,
#  'road': 9203,
#  'restriction': 9097,
#  'movement': 7140,
#  'friend': 4474,
#  'left': 6335,
#  'abbottabad': 899,
#  'contain': 2820,
#  'usa': 11143,
#  'could': 2907,
#  'contained': 2821,
#  'dear': 3151,
#  'avneesh': 1547,
#  'tiwari': 10734,
#  'pratapgarh': 8328,
#  'uttarpradesh': 11176,
#  'currently': 3035,
#  'varanasi': 11236,
#  'unable': 11016,
#  'town': 10807,
#  'bike': 1907,
#  'department': 3269,
#  'allow': 1182,
#  'reach': 8799,
#  'muna': 7198,
#  'kami': 5912,
#  'uniform': 11055,
#  'kadam': 5888,
#  'behram': 1809,
#  'baug': 1748,
#  'jogeshwari': 5810,
#  'west': 11580,
#  'mumbai': 7195,
#  '400102': 520,
#  'come': 2648,
#  'strict': 10194,
#  'action': 973,
#  'anything': 1305,
#  'seriously': 9617,
#  'seems': 9564,
#  'paridhabangal': 7911,
#  'pesuiyyqbb': 8063,
#  'power': 8299,
#  'supply': 10323,
#  'interrupt': 5598,
#  'netaji': 7403,
#  'pac': 7826,
#  'audioconferencing': 1512,
#  'chief': 2471,
#  'secretary': 9543,
#  'dgp': 3354,
#  'secretaries': 9542,
#  'collectors': 2636,
#  'regional': 8902,
#  'adminstrators': 1023,
#  'reviewed': 9129,
#  'planned': 8157,
#  'ahead': 1096,
#  'repeat': 8997,
#  'message': 6911,
#  'planning': 8158,
#  'delivery': 3243,
#  'understanding': 11036,
#  'abiding': 909,
#  'fky2tra2cp': 4330,
#  'complete': 2706,
#  'going': 4709,
#  'stitching': 10149,
#  'meeting': 6875,
#  'friends': 4476,
#  'continues': 2835,
#  'bit': 1926,
#  'making': 6671,
#  'masks': 6800,
#  'qupnsxivwf': 8673,
#  'saab': 9309,
#  'udh': 10983,
#  'forum': 4431,
#  'yeah': 11862,
#  'look': 6501,
#  'pnb': 8208,
#  'customers': 3045,
#  'omjg7hscqf': 7680,
#  'family': 4178,
#  'alsl': 1200,
#  'lot': 6520,
#  'countries': 2917,
#  'arw': 1426,
#  'kept': 5999,
#  'isolation': 5665,
#  'rikshwa': 9165,
#  'wala': 11467,
#  'foods': 4396,
#  'tell': 10542,
#  'since': 9810,
#  'someway': 9945,
#  'social': 9915,
#  'distancing': 3513,
#  'mind': 6975,
#  'online': 7693,
#  'survey': 10360,
#  'form': 4422,
#  'usp': 11157,
#  'send': 9591,
#  'twt': 10953,
#  'means': 6849,
#  'total': 10790,
#  'data': 3114,
#  '2gb': 436,
#  '5gb': 616,
#  'two': 10951,
#  'finished': 4301,
#  'showing': 9749,
#  'exhausted': 4052,
#  'attached': 1490,
#  'screenshot': 9511,
#  'arr74oxxbq': 1399,
#  'year': 11863,
#  'kid': 6061,
#  'stuck': 10215,
#  'patna': 7969,
#  'law': 6295,
#  'house': 5182,
#  'self': 9577,
#  'weeks': 11561,
#  'bring': 2099,
#  'jamshedpur': 5741,
#  'important': 5373,
#  'historical': 5083,
#  'announcement': 1275,
#  'made': 6608,
#  'hon': 5132,
#  'narendra': 7299,
#  'modiji': 7069,
#  'fight': 4268,
#  'mahamari': 6632,
#  'covid19': 2938,
#  'lockfown': 6478,
#  'distence': 3518,
#  'volenteryl': 11399,
#  'leader': 6312,
#  'lauds': 6286,
#  'modi': 7067,
#  'measures': 6854,
#  'combat': 2645,
#  'html': 5208,
#  'namo': 7285,
#  '0erxi0fcmu': 24,
#  'man': 6696,
#  'indian': 5432,
#  'surgical': 10350,
#  'strike': 10199,
#  'indians': 5433,
#  'relegation': 8945,
#  'meetings': 6876,
#  'ืออะไร': 12108,
#  'ในเมื่': 12131,
#  'เราสู้': 12123,
#  'staying': 10123,
#  'cant': 2257,
#  'fit': 4315,
#  'workout': 11706,
#  'importantly': 5374,
#  'guscw02mpf': 4852,
#  'r78fyg2nu64d': 8681,
#  'mha': 6931,
#  'guidelines': 4831,
#  'study': 10224,
#  'wfh': 11585,
#  'affected': 1063,
#  'recvd': 8869,
#  'forward': 4432,
#  'true': 10905,
#  'let’': 6364,
#  'design': 3301,
#  'economic': 3760,
#  'ecosystem': 3763,
#  'planet': 8156,
#  'earth': 3738,
#  'might': 6945,
#  'saved': 9455,
#  'sh3gzie5mx': 9651,
#  'little': 6439,
#  'boring': 2026,
#  'saftey': 9342,
#  'others': 7767,
#  '10cxttqwad': 68,
#  'alamgari': 1150,
#  'bazar': 1751,
#  'stamping': 10082,
#  'thousands': 10667,
#  'citizens': 2534,
#  'indelible': 5425,
#  'ink': 5502,
#  'posting': 8280,
#  'notices': 7518,
#  'tracing': 10818,
#  'violators': 11342,
#  'spoke': 10030,
#  'intl': 5607,
#  'fliers': 4351,
#  'landed': 6249,
#  'bengaluru': 1837,
#  'dept': 3286,
#  'dealing': 3149,
#  'foreign': 4411,
#  'returnees': 9117,
#  'karnataka': 5943,
#  'tracking': 10821,
#  'represent': 9016,
#  'speak': 9991,
#  'kids': 6065,
#  'damn': 3097,
#  'rest': 9085,
#  'aren’': 1381,
#  'studies': 10221,
#  'low': 6536,
#  'bangalore': 1684,
#  'h1gxuu06ggj': 4873,
#  'taxing': 10489,
#  'phewwwwwww': 8085,
#  'society': 9918,
#  'girl': 4666,
#  'another': 1281,
#  'london': 6494,
#  'britain': 2103,
#  'bunglows': 2155,
#  'side': 9780,
#  'front': 4484,
#  'raat': 8686,
#  'nindiya': 7463,
#  'haram': 4932,
#  'kar': 5926,
#  'inho': 5491,
#  'taxes': 10488,
#  'essentaials': 3977,
#  'medicine': 6864,
#  'recover': 8860,
#  'pointing': 8224,
#  'saying': 9466,
#  'correct': 2894,
#  'talking': 10449,
#  'blame': 1940,
#  'game': 4556,
#  'else': 3829,
#  'safely': 9333,
#  'newsalert': 7417,
#  'greater': 4781,
#  'resident': 9046,
#  'discharged': 3464,
#  'gims': 4659,
#  'successfully': 10259,
#  'treated': 10871,
#  'tests': 10582,
#  'came': 2237,
#  'negative': 7375,
#  'confirms': 2758,
#  'recovery': 8863,
#  'patient': 7965,
#  'says': 9467,
#  'director': 3451,
#  'brig': 2095,
#  'rakesh': 8740,
#  'gupta': 4842,
#  'okbaecnsnb': 7662,
#  'safeguard': 9332,
#  'اللہ': 12010,
#  'رہم': 12011,
#  'tldjspa3m9': 10741,
#  'fun': 4507,
#  'play': 8172,
#  'josh': 5830,
#  'got': 4735,
#  'everything': 4009,
#  'phupho': 8101,
#  'prevention': 8396,
#  'epidemic': 3945,
#  'fpplmjnysr': 4445,
#  'create': 2955,
#  'positivity': 8273,
#  'around': 1398,
#  'diverting': 3544,
#  'sharing': 9681,
#  'enjoy': 3910,
#  'even': 3997,
#  'raise': 8721,
#  'voice': 11395,
#  'ourseleves': 7776,
#  'donate': 3597,
#  'retweet': 9120,
#  'realise': 8819,
#  'roots': 9236,
#  'breathing': 2088,
#  'values': 11227,
#  'value': 11225,
#  'chance': 2401,
#  'quality': 8645,
#  'surat': 10336,
#  'information': 5482,
#  'city': 2535,
#  'near': 7350,
#  'goenka': 4705,
#  'international': 5592,
#  'school': 9492,
#  'foreigner': 4412,
#  'living': 6448,
#  'among': 1236,
#  '’': 12165,
#  'serving': 9629,
#  'requires': 9034,
#  'maintain': 6657,
#  'structured': 10211,
#  'routine': 9244,
#  'r8kdom4tl9': 8683,
#  'sonia': 9956,
#  'gandhi': 4561,
#  'rahul': 8710,
#  'robert': 9210,
#  'vadra': 11209,
#  'start': 10093,
#  'distributing': 3527,
#  'accumulated': 952,
#  'wealth': 11534,
#  'poor': 8247,
#  'charity': 2428,
#  'begins': 1798,
#  'banglow': 1689,
#  'occupied': 7614,
#  'spared': 9988,
#  'ward': 11487,
#  'patients': 7966,
#  'convey': 2856,
#  'perfect': 8031,
#  'opportunity': 7723,
#  'earn': 3731,
#  'join': 5817,
#  'contact': 2815,
#  '6w7q9ehkn5': 681,
#  'isn’': 5660,
#  'affecting': 1064,
#  'graphic': 4773,
#  'designing': 3304,
#  'branding': 2067,
#  'timely': 10714,
#  'guaranteed': 4817,
#  'better': 1850,
#  'productive': 8452,
#  'rather': 8777,
#  'goers': 4706,
#  'panicking': 7884,
#  'productivity': 8455,
#  'digital': 3427,
#  'nomads…': 7494,
#  'y5zg2c25tgu2': 11840,
#  'implementing': 5370,
#  'section': 9546,
#  '144': 127,
#  'roaming': 9207,
#  'colaba': 2622,
#  'market': 6772,
#  'without': 11663,
#  'precautions': 8344,
#  'strong': 10204,
#  'reason': 8830,
#  'moment': 7082,
#  'van': 11230,
#  'goes': 4707,
#  'patrolling': 7971,
#  'imjetilyy3': 5347,
#  'addressed': 1005,
#  'honorable': 5140,
#  'required': 9031,
#  'teleperformance': 10535,
#  'management': 6701,
#  'giving': 4676,
#  'gyan': 4865,
#  'balcony': 1658,
#  'star': 10089,
#  'managing': 6704,
#  '130': 112,
#  'dare': 3108,
#  'manage': 6698,
#  'ground': 4794,
#  'enforce': 3894,
#  'elitist': 3826,
#  'gang': 4563,
#  'vip': 11345,
#  'privileges': 8425,
#  'aside': 1441,
#  'full': 4505,
#  'die': 3407,
#  'professional': 8459,
#  'lose': 6515,
#  'job': 5807,
#  'deliver': 3235,
#  'login': 6486,
#  'aws': 1576,
#  'account': 949,
#  'ceo': 2349,
#  'wework': 11583,
#  'millions': 6971,
#  'invent': 5618,
#  'outsource': 7794,
#  'sone': 9951,
#  'movable': 7137,
#  'cabins': 2212,
#  'spaces': 9979,
#  'box': 2048,
#  'installed': 5541,
#  'homes': 5117,
#  'noise': 7491,
#  'proof': 8487,
#  'hit': 5085,
#  'calcutta': 2224,
#  'big': 1897,
#  'basket': 1733,
#  'claims': 2544,
#  'awaiting': 1557,
#  'authorities': 1526,
#  'despite': 3313,
#  'clear': 2564,
#  'encouraged': 3878,
#  'success': 10257,
#  ...}

# %%
# example of vectorized text
sample_tweet = df_lockdown['tweet'][10]
print(sample_tweet)
print('\n')
# vector representation
bow_sample = bow_transformer.transform([sample_tweet])
print(bow_sample)
print('\n')
# Out:
# mohalla clinic doctor from mohanpuri maujpur area gopal jha found request all those who visited there between 12th march 18th march follow home quarantine for days pic twitter com xouum13ekv
#
#
#   (0, 110)	1
#   (0, 186)	1
#   (0, 1379)	1
#   (0, 2576)	1
#   (0, 2644)	1
#   (0, 3130)	1
#   (0, 3573)	1
#   (0, 4386)	1
#   (0, 4435)	1
#   (0, 4726)	1
#   (0, 5109)	1
#   (0, 5775)	1
#   (0, 6757)	2
#   (0, 6825)	1
#   (0, 7072)	1
#   (0, 7076)	1
#   (0, 8108)	1
#   (0, 8647)	1
#   (0, 9025)	1
#   (0, 10950)	1
#   (0, 11368)	1
#   (0, 11815)	1

# %%
messages_bow = bow_transformer.transform(df_lockdown['tweet'])

# check out the bag-of-words counts for the entire corpus as a large sparse matrix
print('Shape of Sparse Matrix: ', messages_bow.shape)
print('Amount of Non-Zero occurences: ', messages_bow.nnz)
# Out:
# Shape of Sparse Matrix:  (4074, 12304)
# Amount of Non-Zero occurences:  69503

# %%
from sklearn.feature_extraction.text import TfidfTransformer
tfidf_transformer = TfidfTransformer().fit(messages_bow)
tfidf_sample = tfidf_transformer.transform(bow_sample)
print(tfidf_sample)
# Out:
#   (0, 11815)	0.2780450775027658
#   (0, 11368)	0.2295269102363274
#   (0, 10950)	0.07349085707939222
#   (0, 9025)	0.13855824527716704
#   (0, 8647)	0.1139306173652864
#   (0, 8108)	0.07394882764258097
#   (0, 7076)	0.2780450775027658
#   (0, 7072)	0.2649656814703137
#   (0, 6825)	0.2780450775027658
#   (0, 6757)	0.32579989892948097
#   (0, 5775)	0.24848759123972988
#   (0, 5109)	0.033615841424580455
#   (0, 4726)	0.2780450775027658
#   (0, 4435)	0.21096695189816309
#   (0, 4386)	0.159050090433593
#   (0, 3573)	0.20219497944415385
#   (0, 3130)	0.1212784166755342
#   (0, 2644)	0.07377632584261715
#   (0, 2576)	0.2649656814703137
#   (0, 1379)	0.16624820149509464
#   (0, 186)	0.25568570230123155
#   (0, 110)	0.24848759123972988

# %%
messages_tfidf = tfidf_transformer.transform(messages_bow)
print(messages_tfidf.shape)
# Out:
# (4074, 12304)

# %% [markdown]
# # Run Train Data Through Pipeline analyzer on the dataset.

# %%
X_train, X_test, y_train, y_test = train_test_split(data['SentimentText'][:5000], data['Sentiment'][:5000], test_size=0.2)


# create pipeline
pipeline = Pipeline([
    ('bow', CountVectorizer(strip_accents='ascii',
                            stop_words='english',
                            lowercase=True)),  # strings to token integer counts
    ('tfidf', TfidfTransformer()),  # integer counts to weighted TF-IDF scores
    ('classifier', MultinomialNB()),  # train on TF-IDF vectors w/ Naive Bayes classifier
])

# this is where we define the values for GridSearchCV to iterate over
parameters = {'bow__ngram_range': [(1, 1), (1, 2)],
              'tfidf__use_idf': (True, False),
              'classifier__alpha': (1e-2, 1e-3),
             }

# do 10-fold cross validation for each of the 6 possible combinations of the above params
grid = GridSearchCV(pipeline, cv=10, param_grid=parameters, verbose=1)
grid.fit(X_train,y_train)

# summarize results
print("\nBest Model: %f using %s" % (grid.best_score_, grid.best_params_))
print('\n')
means = grid.cv_results_['mean_test_score']
stds = grid.cv_results_['std_test_score']
params = grid.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("Mean: %f Stdev:(%f) with: %r" % (mean, stdev, param))
# Out:
# Fitting 10 folds for each of 8 candidates, totalling 80 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  80 out of  80 | elapsed:   27.1s finished
# Best Model: 0.754250 using {'bow__ngram_range': (1, 2), 'classifier__alpha': 0.01, 'tfidf__use_idf': False}
#
#
# Mean: 0.744000 Stdev:(0.014867) with: {'bow__ngram_range': (1, 1), 'classifier__alpha': 0.01, 'tfidf__use_idf': True}
# Mean: 0.747750 Stdev:(0.017715) with: {'bow__ngram_range': (1, 1), 'classifier__alpha': 0.01, 'tfidf__use_idf': False}
# Mean: 0.741250 Stdev:(0.015140) with: {'bow__ngram_range': (1, 1), 'classifier__alpha': 0.001, 'tfidf__use_idf': True}
# Mean: 0.745500 Stdev:(0.019030) with: {'bow__ngram_range': (1, 1), 'classifier__alpha': 0.001, 'tfidf__use_idf': False}
# Mean: 0.746750 Stdev:(0.018238) with: {'bow__ngram_range': (1, 2), 'classifier__alpha': 0.01, 'tfidf__use_idf': True}
# Mean: 0.754250 Stdev:(0.019521) with: {'bow__ngram_range': (1, 2), 'classifier__alpha': 0.01, 'tfidf__use_idf': False}
# Mean: 0.743250 Stdev:(0.021189) with: {'bow__ngram_range': (1, 2), 'classifier__alpha': 0.001, 'tfidf__use_idf': True}
# Mean: 0.747250 Stdev:(0.021706) with: {'bow__ngram_range': (1, 2), 'classifier__alpha': 0.001, 'tfidf__use_idf': False}

# %% [markdown]
# # Save best model to current working directory

# %%
joblib.dump(grid, "twitter_sentiment.pkl")
# Out:
# ['twitter_sentiment.pkl']

# %% [markdown]
# # Get predictions from best model above

# %%
model_NB = joblib.load("twitter_sentiment.pkl" )

y_preds = model_NB.predict(X_test)

print('accuracy score: ',accuracy_score(y_test, y_preds))
print('\n')
print('confusion matrix: \n',confusion_matrix(y_test,y_preds))
print('\n')
print(classification_report(y_test, y_preds))
# Out:
# accuracy score:  0.773
#
#
# confusion matrix:
#  [[661  62]
#  [165 112]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.91      0.85       723
#            1       0.64      0.40      0.50       277
#
#     accuracy                           0.77      1000
#    macro avg       0.72      0.66      0.68      1000
# weighted avg       0.76      0.77      0.75      1000

# %% [markdown]
# # Run predictions on twitter data of Lockdown1.0

# %%
tweet_preds = model_NB.predict(df_lockdown['tweet'])

# append predictions to dataframe
df_tweet_preds = df_lockdown.copy()
df_tweet_preds['predictions'] = tweet_preds
df_tweet_preds.shape
# Out:
# (4074, 36)

# %% [markdown]
# # Print text and sentiment

# %%
index = random.sample(range(tweet_preds.shape[0]), 20)
for text, sentiment in zip(df_tweet_preds.tweet[index],
                           df_tweet_preds.predictions[index]):
    print (sentiment, '--', text, '\n')
# Out:
# 1 -- visitors barred from nursing homes until apr after covid cases detected old age home nursing homes visitors april lee mooi cluster thomson 12599654 xovd u6ucvs twitter …
#
# 0 -- was working yesterday supply aswaaq with flowers bouquets had gov permit and from work early the there were only few trucks vans returned home around 3pm was shocked see how many blacked out cars there were the roads during the curfew
#
# 0 -- hey lot employees need broadband work from home can you give one poc who can help this matter this for delhi ncr location
#
# 0 -- make your mask yourself without mask please don come out from home take your responsibility save our life and help our government defeat covid beaing responsible citizen india …
#
# 0 -- rahul home work modi and his anti people bjp team before announcing lock down very inhuman very miserable for poor people bjp won come power congress demands removes evms from india think plan this direction
#
# 0 -- during this lockdown you can start your record breaking journey with maac lucknow call 830 3000 300 log http maacanimationlucknow com attend free online career counselling join the course start attending classes from home pic twitter com 6jxgxyoy9w
#
# 0 -- plz needful for people stuck delhi outside himachal govt already doing work making people reach there home himachal action from you
#
# 1 -- modi the laborers who are going their homes from the state please make them corona test before reaching home else corona chain untopable corona reach villages
#
# 0 -- working amazon com banglore india now leave work from home but due bad network facility area amethi unable work kindly help recharged just before yesterday for 399 plan
#
# 0 -- that weird moment when migrant labourers from bihar want back home and shiv sena wants them stay mumbai pic twitter com kbfezffchd
#
# 0 -- need transport raw material chemicals for manufacturing masks garment essential ppe covid from chennai surat urgently can railways help there any epass for this
#
# 0 -- when can “work from home” why can’ “workout from home”  join online sessions zenith dance workout every evening live from our facebook and instagram page  stay home stay safe and keep… igshid 1vp9o0neqx8hr …
#
# 0 -- you really represent why don’ you speak for your kids have broadband you don’ give damn about rest the people aren’ our studies suffering because this low speed internet work from home possible
#
# 1 -- reaching out your employees was not part your social media strategy add now working from home they need reassurance the most pic twitter com iwbfzp0tbt
#
# 0 -- lol hightime they come with data plans suited for lockdown and work from home
#
# 0 -- let contribute the fight against work from home and work online maintain social distancing help help you pic twitter com kwy2ljpwpf
#
# 1 -- they are working from feb start procurement n96 mask ppe kits
# from fab established brand new hospital and quarantine center new raipur etc
#
# 1 -- madam you please remain your home and protect yourself from pandemic the interest your health and for integrity nation
#
# 0 -- work from home going
#
# 0 -- some interesting pics work from home and relaxing videos some funny videos event during working time

# %% [markdown]
# # Testing random text

# %%
# load model
model_NB = joblib.load("twitter_sentiment.pkl" )

# test string (positive)
sample_str = """Goverment of india is working hard for the well being of the people of India"""

# test string (negative)
sample_strn = """The government is foolish to impose lockdown. The economy is going to worsen."""

p = model_NB.predict([sample_str])
k = model_NB.predict([sample_strn])

# formatting helper
def sentiment_str(x):
    if x==0:
        return 'Negative'
    else:
        return 'Positive'
#_____________________________________________

# test result ___ 0=Negative, 1=Positive
print("the sentence: \n\n'{}' \n\nhas a {} sentiment".format(sample_str,sentiment_str(p[0])))
print("the sentence: \n\n'{}' \n\nhas a {} sentiment".format(sample_strn,sentiment_str(k[0])))
# Out:
# the sentence:
#
# 'Goverment of india is working hard for the well being of the people of India'
#
# has a Negative sentiment
# the sentence:
#
# 'The government is foolish to impose lockdown. The economy is going to worsen.'
#
# has a Negative sentiment

# %%
df_tweet_preds.to_csv('Lockdown1labelled.csv')

# %%
df_tweet_pred
